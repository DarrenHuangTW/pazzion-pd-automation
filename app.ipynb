# %%
import pandas as pd
import anthropic
import requests
from dotenv import load_dotenv
import base64

import csv
from io import BytesIO
from PIL import Image

load_dotenv()
client = anthropic.Anthropic()

# %%
def load_few_shot_examples(csv_file):
    examples = []
    with open(csv_file, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            examples.append({
                'product_name': row['Product_Name'],
                'product_images': eval(row['Product_Images']),
                'product_description': row['Product_Description']
            })
    return examples


def download_and_encode_image(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        image = Image.open(BytesIO(response.content))
        
        # Determine the correct media type
        if image.format.lower() == 'jpeg':
            media_type = 'image/jpeg'
        elif image.format.lower() == 'png':
            media_type = 'image/png'
        elif image.format.lower() == 'gif':
            media_type = 'image/gif'
        elif image.format.lower() == 'webp':
            media_type = 'image/webp'
        else:
            print(f"Unsupported image format: {image.format}")
            return None, None

        buffered = BytesIO()
        image.save(buffered, format=image.format)
        encoded_image = base64.b64encode(buffered.getvalue()).decode('utf-8')
        return encoded_image, media_type
    except Exception as e:
        print(f"Error downloading or encoding image: {e}")
        return None, None

# %%
def load_few_shot_pd(few_shot_examples):
    example_messages = []

    for example in few_shot_examples:
        # Prepare user message with product name and images
        user_content = [
            {
                "type": "text", 
                "text": f"Product Name: {example['product_name']}\nProduct Images:"
                }
            ]

        # Download and encode up to 5 valid images
        encoded_images = []
        for url in example['product_images']:
            if len(encoded_images) >= 5:
                break
            encoded_image, media_type = download_and_encode_image(url)
            if encoded_image and media_type:
                encoded_images.append((encoded_image, media_type))

        # Add encoded images to user content
        user_content.extend([
            {
                "type": "image",
                "source": {
                    "type": "base64",
                    "media_type": media_type,
                    "data": image_data
                }
            } for image_data, media_type in encoded_images
        ])

        # Add user message to example_messages
        example_messages.append({
            "role": "user",
            "content": user_content,
            "cache_control": {"type": "ephemeral"}
        })

        # Add assistant message (product description) to example_messages
        example_messages.append({
            "role": "assistant",
            "content": example['product_description']
        })

    return example_messages

# %%
few_shot_examples = load_few_shot_examples('examples/examples_sarcastic.csv')
example_messages = load_few_shot_pd(few_shot_examples[:3]) # load only 3 products to save money
example_messages
# Out:
# [{'role': 'user',
#   'content': [{'type': 'text',
#     'text': 'Product Name: Phoenix Knot Detail Suede Loafers\nProduct Images:'},
#    {'type': 'image',
#     'source': {'type': 'base64',
#      'media_type': 'image/jpeg',
#      'data': '...'}},
#    {'type': 'image',
#     'source': {'type': 'base64',
#      'media_type': 'image/jpeg',
#      'data': '...'}},
#    {'type': 'image',
#     'source': {'type': 'base64',
#      'media_type': 'image/jpeg',
#      'data': '...'}},
#    {'type': 'image',
#     'source': {'type': 'base64',
#      'media_type': 'image/jpeg',
#      'data': '...'}},
#    {'type': 'image',
#     'source': {'type': 'base64',
#      'media_type': 'image/jpeg',
#      'data': '...'}}],
#   'cache_control': {'type': 'ephemeral'}},
#  {'role': 'assistant',
#   'content': 'Oh, joy! Behold these revolutionary loafers, featuring mind-blowing "knot detailing" and "gold-tone hardware" that will surely blind onlookers with their sheer magnificence. The groundbreaking "moc stitching" (because regular stitching is so pass?) accentuates the almond toe design 嚙碾 because who doesn\'t want their feet to resemble nuts? And let\'s not forget the branded leather insole, guaranteeing comfort so luxurious you\'ll forget you\'re even wearing shoes! The rubber grip? It\'s like having your very own personal gravity field! With a flat leather sole that screams " love blisters" and a slip-on style that says "I\'m too important for laces," these loafers are the pinnacle of fashion evolution. Why settle for mere shoes when you can have the "epitome of laid-back elegance" adorning your feet? After all, nothing says "touch of class" quite like overpriced, glorified slippers. Your outfit (and bank account) will thank you!x'},
#  {'role': 'user',
#   'content': [{'type': 'text',
#     'text': 'Product Name: Nevaeh Diamante Platform Loafers\nProduct Images:'},
#    {'type': 'image',
#     'source': {'type': 'base64',
#      'media_type': 'image/jpeg',
#      'data': '...'}},
#    {'type': 'image',
#     'source': {'type': 'base64',
#      'media_type': 'image/jpeg',
#      'data': '...'}},
#    {'type': 'image',
#     'source': {'type': 'base64',
#      'media_type': 'image/jpeg',
#      'data': '...'}},
#    {'type': 'image',
#     'source': {'type': 'base64',
#      'media_type': 'image/jpeg',
#      'data': '...'}},
#    {'type': 'image',
#     'source': {'type': 'base64',
#      'media_type': 'image/jpeg',
#      'data': '...'}}],
#   'cache_control': {'type': 'ephemeral'}},
#  {'role': 'assistant',
#   'content': 'Oh boy, prepare to be absolutely dazzled by the Nevaeh Diamante Platform Loafers, the epitome of sophistication and comfort! Because nothing says "I\'m a practical, down-to-earth person" like strutting around in platform shoes covered in fake diamonds. These loafers are so versatile, you can wear them anywhere - from grocery shopping to black-tie galas! Who needs different shoes for different occasions when you can blind everyone with your sparkling feet all day long? Crafted from "premium materials" (whatever that means), these babies will definitely not fall apart after two wears. And let\'s not forget the "chic" platform sole that adds height without sacrificing comfort - because teetering around like a newborn giraffe is the pinnacle of elegance. The delicate diamante on the upper "catches the light and sparkles with every move" - perfect for those who\'ve always dreamed of being a walking disco ball. Why settle for boring, comfortable shoes when you can have these glamorous foot prisons that transition seamlessly from causing blisters during the day to crippling your feet at night? Pair them with literally anything, because who cares about coordinating when your feet are this fabulous?'},
#  {'role': 'user',
#   'content': [{'type': 'text',
#     'text': 'Product Name: Marie Crystal Embellished Flyknit Sneakers\nProduct Images:'},
#    {'type': 'image',
#     'source': {'type': 'base64',
#      'media_type': 'image/jpeg',
#      'data': '...'}},
#    {'type': 'image',
#     'source': {'type': 'base64',
#      'media_type': 'image/jpeg',
#      'data': '...'}},
#    {'type': 'image',
#     'source': {'type': 'base64',
#      'media_type': 'image/jpeg',
#      'data': '...'}},
#    {'type': 'image',
#     'source': {'type': 'base64',
#      'media_type': 'image/jpeg',
#      'data': '...'}},
#    {'type': 'image',
#     'source': {'type': 'base64',
#      'media_type': 'image/jpeg',
#      'data': '...'}}],
#   'cache_control': {'type': 'ephemeral'}},
#  {'role': 'assistant',
#   'content': 'Behold, the Marie sneakers - where "innovation" meets "glamour" in a dazzling display of marketing buzzwords! These groundbreaking shoes will absolutely revolutionize the way you walk, thanks to their mind-blowing "lightweight comfort" (because apparently, other shoes are made of lead). But wait, there\'s more! Feast your eyes on the awe-inspiring "squared grommet crystal embellishment" at the front - because nothing says "modern elegance" like a chunk of plastic masquerading as jewelry on your feet. The flyknit material ensures unparalleled breathability, perfect for those who\'ve always dreamed of their feet sweating slightly less. Why settle for ordinary sneakers when you can have these trendsetting masterpieces that scream "I have more money than sense"? Pair them with a Caroline cross body bag for the ultimate "I\'m trying too hard" ensemble. After all, who doesn\'t want their feet to make a "statement" - even if that statement is "I fell for overpriced footwear"?'}]

# %%
def process_row(row):
    # Prepare user message with product name and images
    user_content = [{"type": "text", "text": f"Product Name: {row['product_name']}\nProduct Images:"}]

    # Download and encode images
    encoded_images = []
    for url in row['product_images']:
        if len(encoded_images) >= 5:
            break
        encoded_image, media_type = download_and_encode_image(url)
        if encoded_image and media_type:
            encoded_images.append((encoded_image, media_type))

    # Add encoded images to user content
    user_content.extend([
        {
            "type": "image",
            "source": {
                "type": "base64",
                "media_type": media_type,
                "data": image_data
            }
        } for image_data, media_type in encoded_images
    ])

    # Prepare the messages for the API call
    messages = example_messages + [
        {"role": "user", "content": user_content}
    ]

    # Make the API call
    response = client.messages.create(
        model="claude-3-5-sonnet-20240620", # claude-3-5-sonnet-20240620
        max_tokens=1000,
        messages=messages,
        extra_headers={"anthropic-beta": "prompt-caching-2024-07-31"}
    )

    # Extract the generated description
    generated_description = response.content[0].text
    
    input_tokens = response.usage.input_tokens
    output_tokens = response.usage.output_tokens

    return generated_description, input_tokens, output_tokens, response

# %%
products = []
with open('demo/batch_1.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        products.append({
            'URL': row['URL'],
            'product_name': row['Product_Name'],
            'product_images': eval(row['Product_Images']),
        })

# %%
test = products[0]
process_row(test)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[38], line 2
#       1 test = products[0]
# ----> 2 process_row(test)
#
# Cell In[36], line 32, in process_row(row)
#      27 messages = example_messages + [
#      28     {"role": "user", "content": user_content}
#      29 ]
#      31 # Make the API call
# ---> 32 response = client.messages.create(
#      33     model="claude-3-5-sonnet-20240620", # claude-3-5-sonnet-20240620
#      34     max_tokens=1000,
#      35     messages=messages,
#      36     extra_headers={"anthropic-beta": "prompt-caching-2024-07-31"}
#      37 )
#      39 # Extract the generated description
#      40 generated_description = response.content[0].text
#
# File c:\Users\USER\AppData\Local\pypoetry\Cache\virtualenvs\crew-ai-nJciaeOD-py3.12\Lib\site-packages\anthropic\_utils\_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File c:\Users\USER\AppData\Local\pypoetry\Cache\virtualenvs\crew-ai-nJciaeOD-py3.12\Lib\site-packages\anthropic\resources\messages.py:878, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     871 if model in DEPRECATED_MODELS:
#     872     warnings.warn(
#     873         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     874         DeprecationWarning,
#     875         stacklevel=3,
#     876     )
# --> 878 return self._post(
#     879     "/v1/messages",
#     880     body=maybe_transform(
#     881         {
#     882             "max_tokens": max_tokens,
#     883             "messages": messages,
#     884             "model": model,
#     885             "metadata": metadata,
#     886             "stop_sequences": stop_sequences,
#     887             "stream": stream,
#     888             "system": system,
#     889             "temperature": temperature,
#     890             "tool_choice": tool_choice,
#     891             "tools": tools,
#     892             "top_k": top_k,
#     893             "top_p": top_p,
#     894         },
#     895         message_create_params.MessageCreateParams,
#     896     ),
#     897     options=make_request_options(
#     898         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     899     ),
#     900     cast_to=Message,
#     901     stream=stream or False,
#     902     stream_cls=Stream[RawMessageStreamEvent],
#     903 )
#
# File c:\Users\USER\AppData\Local\pypoetry\Cache\virtualenvs\crew-ai-nJciaeOD-py3.12\Lib\site-packages\anthropic\_base_client.py:1260, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1246 def post(
#    1247     self,
#    1248     path: str,
#    (...)
#    1255     stream_cls: type[_StreamT] | None = None,
#    1256 ) -> ResponseT | _StreamT:
#    1257     opts = FinalRequestOptions.construct(
#    1258         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1259     )
# -> 1260     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\USER\AppData\Local\pypoetry\Cache\virtualenvs\crew-ai-nJciaeOD-py3.12\Lib\site-packages\anthropic\_base_client.py:937, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     928 def request(
#     929     self,
#     930     cast_to: Type[ResponseT],
#    (...)
#     935     stream_cls: type[_StreamT] | None = None,
#     936 ) -> ResponseT | _StreamT:
# --> 937     return self._request(
#     938         cast_to=cast_to,
#     939         options=options,
#     940         stream=stream,
#     941         stream_cls=stream_cls,
#     942         remaining_retries=remaining_retries,
#     943     )
#
# File c:\Users\USER\AppData\Local\pypoetry\Cache\virtualenvs\crew-ai-nJciaeOD-py3.12\Lib\site-packages\anthropic\_base_client.py:1041, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1038         err.response.read()
#    1040     log.debug("Re-raising status error")
# -> 1041     raise self._make_status_error_from_response(err.response) from None
#    1043 return self._process_response(
#    1044     cast_to=cast_to,
#    1045     options=options,
#    (...)
#    1049     retries_taken=options.get_max_retries(self.max_retries) - retries,
#    1050 )
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.0.cache_control: Extra inputs are not permitted'}}

# %%
import time

for product in products[:3]:
    start_time = time.time()
    print(process_row(product))
    end_time = time.time()
    print(f"Time taken: {end_time - start_time} seconds")
# Out:
# ('Ah, the Karina Studded Bow Ballet Flats - for when you want to look like you\'re trying way too hard to be both edgy and cute at the same time! These revolutionary flats combine the delicate grace of a ballet shoe with the subtlety of a rhinestone-encrusted sledgehammer. The dainty bow screams "I\'m still five years old at heart," while the studs along the edges whisper "but I might key your car if you cross me." \n\nPerfect for those days when you can\'t decide if you want to pirouette or start a bar fight. The pale pink color ensures you\'ll blend right in with all the other basic fashionistas, while the pointy toe offers a great way to stub your toe on every piece of furniture you own. And let\'s not forget the flat sole, because who needs arch support anyway? \n\nPair these bad boys with some white cropped pants and an off-shoulder top for the ultimate "I read one fashion blog and now I think I\'m stylish" look. Remember, nothing says sophistication quite like shoes that look like they were bedazzled by a toddler with access to their mom\'s craft supplies. Truly a masterpiece of modern footwear design!', 10018, 274, Message(id='msg_019Vek4UBWfffX2X52C2iWoD', content=[TextBlock(text='Ah, the Karina Studded Bow Ballet Flats - for when you want to look like you\'re trying way too hard to be both edgy and cute at the same time! These revolutionary flats combine the delicate grace of a ballet shoe with the subtlety of a rhinestone-encrusted sledgehammer. The dainty bow screams "I\'m still five years old at heart," while the studs along the edges whisper "but I might key your car if you cross me." \n\nPerfect for those days when you can\'t decide if you want to pirouette or start a bar fight. The pale pink color ensures you\'ll blend right in with all the other basic fashionistas, while the pointy toe offers a great way to stub your toe on every piece of furniture you own. And let\'s not forget the flat sole, because who needs arch support anyway? \n\nPair these bad boys with some white cropped pants and an off-shoulder top for the ultimate "I read one fashion blog and now I think I\'m stylish" look. Remember, nothing says sophistication quite like shoes that look like they were bedazzled by a toddler with access to their mom\'s craft supplies. Truly a masterpiece of modern footwear design!', type='text')], model='claude-3-5-sonnet-20240620', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=10018, output_tokens=274, cache_creation_input_tokens=0, cache_read_input_tokens=10322)))
# Time taken: 10.527744054794312 seconds
# ('Oh, joy! Behold the Della Slip On Slide Sandals, the epitome of high fashion and practicality combined into one mind-blowing footwear experience! These revolutionary sandals feature the groundbreaking technology of... wait for it... straps that cross over your feet! Who would have thought?\n\nBut wait, there\'s more! These sandals come in the ultra-rare, never-before-seen color of... black! Talk about pushing the boundaries of design. And let\'s not forget the pièce de résistance - a tiny gold logo that screams "I overpaid for basic slides!"\n\nThe chunky sole isn\'t just for show - it\'s perfect for those who\'ve always dreamed of feeling like they\'re walking on a slightly elevated piece of rubber. And the best part? They slip on AND slide! It\'s like they\'ve reinvented walking!\n\nPair these with literally anything, because nothing says "I\'ve given up on life" quite like wearing glorified shower shoes in public. Whether you\'re running errands, attending a wedding, or having a job interview, these sandals will ensure everyone knows you prioritize comfort over social acceptance.\n\nRemember, fashion is pain, but with the Della Slip On Slide Sandals, you can experience the pain of realizing you spent good money on what are essentially fancy flip-flops. Truly a bargain at any price!', 10016, 306, Message(id='msg_01RToaa43iFAGBp93be7tGtp', content=[TextBlock(text='Oh, joy! Behold the Della Slip On Slide Sandals, the epitome of high fashion and practicality combined into one mind-blowing footwear experience! These revolutionary sandals feature the groundbreaking technology of... wait for it... straps that cross over your feet! Who would have thought?\n\nBut wait, there\'s more! These sandals come in the ultra-rare, never-before-seen color of... black! Talk about pushing the boundaries of design. And let\'s not forget the pièce de résistance - a tiny gold logo that screams "I overpaid for basic slides!"\n\nThe chunky sole isn\'t just for show - it\'s perfect for those who\'ve always dreamed of feeling like they\'re walking on a slightly elevated piece of rubber. And the best part? They slip on AND slide! It\'s like they\'ve reinvented walking!\n\nPair these with literally anything, because nothing says "I\'ve given up on life" quite like wearing glorified shower shoes in public. Whether you\'re running errands, attending a wedding, or having a job interview, these sandals will ensure everyone knows you prioritize comfort over social acceptance.\n\nRemember, fashion is pain, but with the Della Slip On Slide Sandals, you can experience the pain of realizing you spent good money on what are essentially fancy flip-flops. Truly a bargain at any price!', type='text')], model='claude-3-5-sonnet-20240620', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=10016, output_tokens=306, cache_creation_input_tokens=0, cache_read_input_tokens=10322)))
# Time taken: 12.524347305297852 seconds
# ('Oh, joy! The Taryn Leather Espadrilles - because nothing says "I\'m ready for summer" quite like overpriced, glorified slippers! These revolutionary shoes combine the comfort of your grandma\'s house shoes with the price tag of a small yacht. The quilted leather upper screams "I have more money than sense," while the jute rope sole whispers "I\'m down to earth, really!" \n\nBut wait, there\'s more! The slip-on style ensures you\'ll never waste precious seconds tying laces again. And let\'s not forget the round toe - because square toes are so last season, darling. The flat rubber sole provides just enough grip to prevent you from face-planting as you strut down the boardwalk, feeling oh-so-chic in your $200 peasant shoes.\n\nPair these bad boys with some flowy linen pants and a straw hat for the ultimate "I summer in the Hamptons" look. Or, if you\'re feeling particularly daring, wear them with socks and shorts to achieve peak "fashion-forward tourist" vibes. \n\nRemember, it\'s not about comfort or practicality - it\'s about making sure everyone knows you can afford to spend a small fortune on shoes that will probably fall apart after one season. Because nothing says "summer" quite like overpriced, impractical footwear!', 10016, 302, Message(id='msg_0144Si88cDQaCVeJbsddHs5W', content=[TextBlock(text='Oh, joy! The Taryn Leather Espadrilles - because nothing says "I\'m ready for summer" quite like overpriced, glorified slippers! These revolutionary shoes combine the comfort of your grandma\'s house shoes with the price tag of a small yacht. The quilted leather upper screams "I have more money than sense," while the jute rope sole whispers "I\'m down to earth, really!" \n\nBut wait, there\'s more! The slip-on style ensures you\'ll never waste precious seconds tying laces again. And let\'s not forget the round toe - because square toes are so last season, darling. The flat rubber sole provides just enough grip to prevent you from face-planting as you strut down the boardwalk, feeling oh-so-chic in your $200 peasant shoes.\n\nPair these bad boys with some flowy linen pants and a straw hat for the ultimate "I summer in the Hamptons" look. Or, if you\'re feeling particularly daring, wear them with socks and shorts to achieve peak "fashion-forward tourist" vibes. \n\nRemember, it\'s not about comfort or practicality - it\'s about making sure everyone knows you can afford to spend a small fortune on shoes that will probably fall apart after one season. Because nothing says "summer" quite like overpriced, impractical footwear!', type='text')], model='claude-3-5-sonnet-20240620', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=10016, output_tokens=302, cache_creation_input_tokens=0, cache_read_input_tokens=10322)))
# Time taken: 12.268280982971191 seconds

# %% [markdown]
# 1. prompt caching
# 2. few shot with input(s)/output(s)

# %%
import anthropic

client = anthropic.Anthropic()

response = client.beta.prompt_caching.messages.create(
    model="claude-3-5-sonnet-20240620",
    max_tokens=1024,
    system=[
      {
        "type": "text", 
        "text": "You are an AI assistant tasked with analyzing literary works. Your goal is to provide insightful commentary on themes, characters, and writing style.\n",
      },
      {
        "type": "text", 
        "text": "<the entire contents of 'Pride and Prejudice'>",
        "cache_control": {"type": "ephemeral"}
      }
    ],
    messages=[{"role": "user", "content": "Analyze the major themes in 'Pride and Prejudice'."}],
)
print(response)
# Out:
# PromptCachingBetaMessage(id='msg_01PpD1bLES7x2S6tj7GTJoFW', content=[TextBlock(text='Certainly! I\'d be happy to analyze the major themes in Jane Austen\'s "Pride and Prejudice" based on the text provided. Here are some of the key themes explored in the novel:\n\n1. Pride and Prejudice: As the title suggests, these two traits are central to the story. Many characters, especially Elizabeth Bennet and Mr. Darcy, must overcome their pride and preconceived notions about others to find happiness.\n\n2. Love and Marriage: The novel explores various motivations for marriage, contrasting marriages based on love with those based on financial security or social expectations.\n\n3. Social Class and Wealth: Austen examines the rigid class structure of Regency-era England and how it impacts relationships and social interactions.\n\n4. Family and Reputation: The importance of family connections and maintaining a good reputation in society is a recurring theme throughout the book.\n\n5. Gender Roles and Expectations: The novel highlights the limited options available to women in the early 19th century, particularly in terms of securing their financial futures.\n\n6. Personal Growth and Self-awareness: Several characters, most notably Elizabeth and Darcy, undergo significant personal development as they learn to look beyond first impressions.\n\n7. Manners and Etiquette: The story is deeply rooted in the social norms and expectations of the time, often using characters\' adherence to or deviation from these norms as a means of characterization.\n\nThese themes are interwoven throughout the narrative, often intersecting and influencing each other as the story progresses. Austen\'s nuanced exploration of these themes contributes to the enduring appeal and relevance of "Pride and Prejudice."', type='text')], model='claude-3-5-sonnet-20240620', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=PromptCachingBetaUsage(cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=66, output_tokens=366))
